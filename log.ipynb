# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
path = "~/PhysarumSDPSolver"

# %%
exp_dir = "experiments_xx_test_2"
testset = "testset0"
testcase = "sample_0"

# %%
f = os.path.join(path, exp_dir, testset, testcase, "logs.csv")
f
# Out:
# '~/PhysarumSDPSolver/experiments_xx_test_2/testset0/sample_0/logs.csv'

# %%
df = pd.read_csv(f)

# %%
step_sizes = df['step-size']
xdot_norms = df['Xdot-norm']
objs = df['obj']
infeasibilities = df['infeasibility']
x_mineigs = df['X-mineig']
xaxis = range(len(objs))

# %%
plt.scatter(xaxis, objs)
plt.yscale('log')
plt.xscale('log')
plt.show()

# %%
plt.scatter(xaxis, xdot_norms)
plt.yscale('log')
plt.xscale('log')
plt.show()

# %%
plt.scatter(xaxis, infeasibilities)
plt.yscale('log')
plt.xscale('log')
plt.show()

# %%
plt.scatter(xaxis, x_mineigs)
plt.yscale('log')
plt.xscale('log')
plt.show()

# %%
plt.scatter(xaxis, step_sizes)
plt.show()
